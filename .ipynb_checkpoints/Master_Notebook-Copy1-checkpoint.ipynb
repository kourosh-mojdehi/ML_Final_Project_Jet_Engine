# %%
# Import the tools you will need
import pandas as pd             # For handling data tables
import numpy as np              # For math and random numbers
import matplotlib.pyplot as plt # For drawing graphs
import json                     # For saving settings to a file
import joblib                   # For saving ML models/tools to files

# Set the magic seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# Define where your files live
DATA_PATH = "./data/" # Change this to wherever you saved the C-MAPSS text files
